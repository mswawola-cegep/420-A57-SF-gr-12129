# %% [markdown]
# # 04 - Infonuagique 1 - Atelier #1

# %% [markdown]
# ### Importation des bibliothèques

# %%
import io
import os
from google.cloud import vision

from utils import display_objects_results, display_image

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# ### Affichage de l'image

# %%
_ = display_image('wakeupcat.jpg')

# %% [markdown]
# ### Instanciation du client

# %%
client = vision.ImageAnnotatorClient()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-4-cd1d04c9069e> in <module>
# ----> 1 client = vision.ImageAnnotatorClient()
#
# ~/420-a57-sf/ateliers/04-infonuagique/.env/lib/python3.8/site-packages/google/cloud/vision_v1/services/image_annotator/client.py in __init__(self, credentials, transport, client_options, client_info)
#     355         else:
#     356             Transport = type(self).get_transport_class(transport)
# --> 357             self._transport = Transport(
#     358                 credentials=credentials,
#     359                 credentials_file=client_options.credentials_file,
#
# ~/420-a57-sf/ateliers/04-infonuagique/.env/lib/python3.8/site-packages/google/cloud/vision_v1/services/image_annotator/transports/grpc.py in __init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info)
#     167
#     168             if credentials is None:
# --> 169                 credentials, _ = auth.default(
#     170                     scopes=self.AUTH_SCOPES, quota_project_id=quota_project_id
#     171                 )
#
# ~/420-a57-sf/ateliers/04-infonuagique/.env/lib/python3.8/site-packages/google/auth/_default.py in default(scopes, request, quota_project_id, default_scopes)
#     362             return credentials, effective_project_id
#     363
# --> 364     raise exceptions.DefaultCredentialsError(_HELP_MESSAGE)
#
# DefaultCredentialsError: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started

# %% [markdown]
# ### Chargement de l'image

# %%
file_name = os.path.abspath('wakeupcat.jpg')

with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = vision.Image(content=content)

# %% [markdown]
# ### Détection des "étiquette" présentes dans l'image

# %%
response = client.label_detection(image=image)
labels = response.label_annotations

# %%
print('Labels:')
for label in labels:
    print(label.description)

# %% [markdown]
# ### Détection d'objets

# %%
objects = client.object_localization(image=image).localized_object_annotations

# %%
print('Number of objects found: {}'.format(len(objects)))
for object_ in objects:
    print('\n{} (confidence: {})'.format(object_.name, object_.score))
    print('Normalized bounding polygon vertices: ')
    for vertex in object_.bounding_poly.normalized_vertices:
        print(' - ({}, {})'.format(vertex.x, vertex.y))

# %%
display_objects_results('wakeupcat.jpg', objects, 0.5)

# %% [markdown]
# ### Avec une autre image

# %%
file_name = os.path.abspath('raptors.jpg')

with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = vision.Image(content=content)

# %%
response = client.label_detection(image=image)
labels = response.label_annotations

# %%
print('Labels:')
for label in labels:
    print(label.description)

# %%
objects = client.object_localization(image=image).localized_object_annotations

# %%
display_objects_results('raptors.jpg', objects, 0.5)
